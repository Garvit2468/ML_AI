# %%
# image processing and computer vision
# image size is 8 bit
# image types   1) True color - it uses RGB, CYMK, HSV, BGR
# yellow = red + green
# m = r + b
# c = g + b
#               2)Grey Scale
#               3)Binary

# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('krishna.jpg')
cv2.imshow('titles',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (261, 236, 3)

# %%
img
# Out:
# array([[[  0, 148, 209],
#         [  0, 142, 202],
#         [  3, 157, 216],
#         ...,
#         [ 28, 173, 199],
#         [  0, 153, 194],
#         [  0, 147, 197]],
#
#        [[  0, 176, 222],
#         [ 23, 192, 236],
#         [ 54, 198, 240],
#         ...,
#         [ 83, 218, 240],
#         [ 15, 198, 237],
#         [  0, 182, 230]],
#
#        [[ 33, 201, 218],
#         [ 50, 203, 218],
#         [111, 230, 245],
#         ...,
#         [101, 215, 228],
#         [ 34, 204, 238],
#         [  0, 197, 240]],
#
#        ...,
#
#        [[  0, 193, 209],
#         [ 37, 214, 229],
#         [ 36, 175, 191],
#         ...,
#         [ 83, 208, 228],
#         [ 40, 204, 223],
#         [ 17, 201, 219]],
#
#        [[  0, 195, 218],
#         [ 23, 212, 233],
#         [ 58, 215, 235],
#         ...,
#         [ 82, 227, 249],
#         [ 43, 214, 238],
#         [ 16, 201, 227]],
#
#        [[  0, 172, 200],
#         [  0, 180, 208],
#         [ 31, 202, 228],
#         ...,
#         [ 37, 199, 227],
#         [  9, 185, 216],
#         [  0, 171, 203]]], dtype=uint8)

# %%
img1 = plt.imread('krishna.jpg')
plt.imshow(img1)
